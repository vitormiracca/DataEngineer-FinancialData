# %%
import stocks

# %%
df_stocks = stocks.br_stocks()
dict_stocks = stocks.br_tickers()

print(dict_stocks)
df_stocks.head()
# Out:
# {'ABCB4': 'ABCB4.SA', 'AGRO3': 'AGRO3.SA', 'RAIL3': 'RAIL3.SA', 'ALPA3': 'ALPA3.SA', 'ALPA4': 'ALPA4.SA', 'ALSO3': 'ALSO3.SA', 'AMAR3': 'AMAR3.SA', 'ABEV3': 'ABEV3.SA', 'ADHM3': 'ADHM3.SA', 'ARZZ3': 'ARZZ3.SA', 'BBAS3': 'BBAS3.SA', 'BBDC3': 'BBDC3.SA', 'BBDC4': 'BBDC4.SA', 'BBRK3': 'BBRK3.SA', 'BEEF3': 'BEEF3.SA', 'BPHA3': 'BPHA3.SA', 'BPAN4': 'BPAN4.SA', 'BRAP3': 'BRAP3.SA', 'BRAP4': 'BRAP4.SA', 'BRFS3': 'BRFS3.SA', 'APER3': 'APER3.SA', 'BRKM3': 'BRKM3.SA', 'BRKM5': 'BRKM5.SA', 'BRML3': 'BRML3.SA', 'BRPR3': 'BRPR3.SA', 'BRSR6': 'BRSR6.SA', 'OIBR3': 'OIBR3.SA', 'OIBR4': 'OIBR4.SA', 'BTOW3': 'BTOW3.SA', 'B3SA3': 'B3SA3.SA', 'CAMB4': 'CAMB4.SA', 'CARD3': 'CARD3.SA', 'CCPR3': 'CCPR3.SA', 'CCRO3': 'CCRO3.SA', 'CEDO4': 'CEDO4.SA', 'CEED3': 'CEED3.SA', 'CESP6': 'CESP6.SA', 'CGAS5': 'CGAS5.SA', 'CGRA4': 'CGRA4.SA', 'CIEL3': 'CIEL3.SA', 'CMIG3': 'CMIG3.SA', 'CMIG4': 'CMIG4.SA', 'COCE5': 'COCE5.SA', 'CPFE3': 'CPFE3.SA', 'CPLE3': 'CPLE3.SA', 'CPLE6': 'CPLE6.SA', 'CRDE3': 'CRDE3.SA', 'CSAN3': '
# ...

# %%
df_stocks_prices = stocks.get_historical_prices_stocks(list(dict_stocks.values()), '1wk', '2018-01-01')
df_stocks_prices
# Out:
# [*********************100%%**********************]  747 of 747 completed
# 151 Failed downloads:
# ...
